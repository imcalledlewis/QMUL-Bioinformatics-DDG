# %% [markdown]
# # Cleaning the GWAS dataset

# %%
import pandas as pd

# %%
data = pd.read_csv('gwas_catalog_v1.0-associations_e108_r2023-01-14.tsv', sep='\t', low_memory=False)
#data =data.loc[data['DISEASE/TRAIT']=='Type 1 diabetes']   # select only rows regarding type 1 diabetes
#data =data.loc[data['CHR_ID']=='6']                        # select only rows for chromosome 6
data.to_csv('gwas_trimmed.tsv', sep='\t')
# Out:
#        DATE ADDED TO CATALOG  PUBMEDID       FIRST AUTHOR        DATE  \
# 14701             2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 14702             2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 19605             2019-08-07  31152121              Zhu M  2019-05-31
# 19607             2019-08-07  31152121              Zhu M  2019-05-31
# 147068            2008-06-16  17632545       Hakonarson H  2007-07-15
#
#               JOURNAL                                  LINK  \
# 14701       Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 14702       Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 19605   Diabetes Care  www.ncbi.nlm.nih.gov/pubmed/31152121
# 19607   Diabetes Care  www.ncbi.nlm.nih.gov/pubmed/31152121
# 147068         Nature  www.ncbi.nlm.nih.gov/pubmed/17632545
#
#                                                     STUDY    DISEASE/TRAIT  \
# 14701   Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 14702   Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 19605   Identification of Novel T1D Risk Loci and Thei...  Type 1 diabetes
# 19607   Identification of Novel T1D Risk Loci and Thei...  Type 1 diabetes
# 147068  A genome-wide association study identifies KIA...  Type 1 diabetes
#
#                                       INITIAL SAMPLE SIZE  \
# 14701   6,683 European ancestry cases, 12,173 European...
# 14702   6,683 European ancestry cases, 12,173 European...
# 19605   1,005 Han Chinese ancestry cases, 1,257 Han Ch...
# 19607   1,005 Han Chinese ancestry cases, 1,257 Han Ch...
# 147068  467 European ancestry trios, 561 European ance...
#
#                                   REPLICATION SAMPLE SIZE  ...  \
# 14701                                                 NaN  ...
# 14702                                                 NaN  ...
# 19605   1,378 Han Chinese ancestry cases, 3,774 Han Ch...  ...
# 19607   1,378 Han Chinese ancestry cases, 3,774 Han Ch...  ...
# 147068  390 European ancestry trios, 1,333 European an...  ...
#
#                                    CONTEXT INTERGENIC RISK ALLELE FREQUENCY  \
# 14701                       intron_variant        0.0                  0.17
# 14702                       intron_variant        1.0                  0.45
# 19605   non_coding_transcript_exon_variant        0.0                  0.28
# 19607                splice_region_variant        0.0                  0.46
# 147068                  intergenic_variant        1.0                  0.13
#
#               P-VALUE PVALUE_MLOG P-VALUE (TEXT) OR or BETA 95% CI (TEXT)  \
# 14701    6.000000e-14   13.221849            NaN       1.20           NaN
# 14702    7.000000e-10    9.154902            NaN       1.12           NaN
# 19605    3.000000e-08    7.522879            NaN       1.26   [1.16-1.36]
# 19607   2.000000e-232  231.698970            NaN       4.28   [3.92-4.68]
# 147068   1.000000e-16   16.000000            NaN       8.30   [6.97-9.89]
#
#          PLATFORM [SNPS PASSING QC]  CNV
# 14701             Illumina [135870]    N
# 14702             Illumina [135870]    N
# 19605   Illumina [787224] (imputed)    N
# 19607   Illumina [787224] (imputed)    N
# 147068            Illumina [543071]    N
#
# [5 rows x 34 columns]
