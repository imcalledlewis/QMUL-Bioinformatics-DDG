# %% [markdown]
# # Cleaning the GWAS dataset

# %%
import pandas as pd

# %%
data = pd.read_csv('gwas_catalog_v1.0-associations_e108_r2023-01-14.tsv', sep='\t', low_memory=False)
data =data.loc[data['DISEASE/TRAIT']=='Type 1 diabetes']
#data =data.loc[data['DISEASE/TRAIT']=='Breast cancer']
data.head()
# Out:
#       DATE ADDED TO CATALOG  PUBMEDID       FIRST AUTHOR        DATE  \
# 14663            2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 14664            2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 14665            2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 14666            2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
# 14667            2018-04-26  25751624  Onengut-Gumuscu S  2015-04-01
#
#          JOURNAL                                  LINK  \
# 14663  Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 14664  Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 14665  Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 14666  Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
# 14667  Nat Genet  www.ncbi.nlm.nih.gov/pubmed/25751624
#
#                                                    STUDY    DISEASE/TRAIT  \
# 14663  Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 14664  Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 14665  Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 14666  Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
# 14667  Fine mapping of type 1 diabetes susceptibility...  Type 1 diabetes
#
#                                      INITIAL SAMPLE SIZE  \
# 14663  6,683 European ancestry cases, 12,173 European...
# 14664  6,683 European ancestry cases, 12,173 European...
# 14665  6,683 European ancestry cases, 12,173 European...
# 14666  6,683 European ancestry cases, 12,173 European...
# 14667  6,683 European ancestry cases, 12,173 European...
#
#       REPLICATION SAMPLE SIZE  ...                             CONTEXT  \
# 14663                     NaN  ...  non_coding_transcript_exon_variant
# 14664                     NaN  ...                      intron_variant
# 14665                     NaN  ...  non_coding_transcript_exon_variant
# 14666                     NaN  ...                  intergenic_variant
# 14667                     NaN  ...                      intron_variant
#
#       INTERGENIC RISK ALLELE FREQUENCY       P-VALUE PVALUE_MLOG  \
# 14663        0.0                  0.34  4.000000e-32   31.397940
# 14664        0.0                  0.48  2.000000e-44   43.698970
# 14665        1.0                  0.24  3.000000e-08    7.522879
# 14666        1.0                  0.27  3.000000e-08    7.522879
# 14667        0.0                  0.59  1.000000e-11   11.000000
#
#       P-VALUE (TEXT) OR or BETA 95% CI (TEXT)  PLATFORM [SNPS PASSING QC]  CNV
# 14663            NaN   1.250000           NaN           Illumina [135870]    N
# 14664            NaN   1.300000           NaN           Illumina [135870]    N
# 14665            NaN   1.120000           NaN           Illumina [135870]    N
# 14666            NaN   1.120000           NaN           Illumina [135870]    N
# 14667            NaN   1.136364           NaN           Illumina [135870]    N
#
# [5 rows x 34 columns]
